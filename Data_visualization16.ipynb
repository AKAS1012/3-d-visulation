# %% [markdown]
# <a href="https://colab.research.google.com/github/AKAS1012/3-d-visulation/blob/master/Data_visualization16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn-white')

# %%
def f(x, y):
    return np.sin(x)**10 + np.cos(10+y*x)*np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 4, 40)

# %%
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
plt.contour(X, Y, Z, colour =" binary");
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: The following kwargs were not used by contour: 'colour'
#   """Entry point for launching an IPython kernel.

# %%
plt.contour(X, Y, Z, 20, camp = "RdGy")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: The following kwargs were not used by contour: 'camp'
#   """Entry point for launching an IPython kernel.

# %%
plt.contour(X, Y, Z, 20, camp = "RdGy")
plt.colorbar();
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: The following kwargs were not used by contour: 'camp'
#   """Entry point for launching an IPython kernel.

# %%
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy')
plt.colorbar()
plt.axis(aspect = 'image')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   after removing the cwd from sys.path.
# (0.0, 5.0, 0.0, 5.0)

# %%
contours = plt.contour(X, Y, Z, 3, color = 'black')
plt.clabel(contours, inline='True', fontsize=9)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: The following kwargs were not used by contour: 'color'
#   """Entry point for launching an IPython kernel.
# <a list of 12 text.Text objects>

# %%
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower', cmap='RdGy', alpha=0.5)
plt.colorbar()
